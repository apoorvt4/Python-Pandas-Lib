# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name":['Apoorv', 'Harry', 'Rohan', 'Shubh'], 
    "marks":[92, 58, 66, 72], 
    "city":['Dindori', 'Rampur', 'Kolkata', 'Bareilly']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks      city
# 0  Apoorv     92   Dindori
# 1   Harry     58    Rampur
# 2   Rohan     66   Kolkata
# 3   Shubh     72  Bareilly

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv', index=False)

# %%
df.head(2)
# Out:
#      name  marks     city
# 0  Apoorv     92  Dindori
# 1   Harry     58   Rampur

# %%
df.tail(1)
# Out:
#     name  marks      city
# 3  Shubh     72  Bareilly

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   72.000000
# std    14.514361
# min    58.000000
# 25%    64.000000
# 50%    69.000000
# 75%    77.000000
# max    92.000000

# %%
apoorv = pd.read_csv('student.csv')

# %%
apoorv
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
apoorv.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
apoorv
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.843743
# 1     0.465114
# 2     0.585162
# 3     0.063251
# 4     0.353774
# 5     0.312305
# 6     0.091038
# 7     0.940245
# 8     0.015783
# 9     0.680097
# 10    0.230374
# 11    0.536618
# 12    0.886358
# 13    0.164578
# 14    0.633580
# 15    0.782646
# 16    0.863645
# 17    0.372896
# 18    0.690526
# 19    0.297177
# 20    0.154954
# 21    0.596946
# 22    0.973092
# 23    0.910148
# 24    0.988966
# 25    0.160034
# 26    0.415481
# 27    0.489686
# 28    0.567459
# 29    0.582157
# 30    0.489706
# 31    0.828610
# 32    0.462336
# 33    0.665469
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334, 10), index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.637477  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2    0.546510  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             7         8         9
# 0    0.781762  0.110817  0.729273
# ...

# %%
newdf.head(554)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.637477  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2    0.546510  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             7         8         9
# 0    0.781762  0.110817  0.729273
# ...

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  334.000000  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.497024    0.519751    0.483236    0.477793    0.492563    0.514325
# std      0.296070    0.291404    0.283388    0.282320    0.285052    0.285249
# min      0.002970    0.001029    0.000789    0.003220    0.000267    0.003315
# 25%      0.234780    0.292176    0.244705    0.234489    0.259083    0.259929
# 50%      0.482922    0.519800    0.469268    0.478029    0.462129    0.546234
# 75%      0.750349    0.777034    0.732363    0.728219    0.750087    0.765952
# max      0.997779    0.998443    0.995171    0.994523    0.998587    0.993962
#
#                 6           7           8           9
# count  334.000000  334.000000  334.000000  334.000000
# mean     0.472039    0.481750    0.518618    0.485651
# std      0.288863    0.287459    0.305238    0.288680
# ...

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# 6    float64
# 7    float64
# 8    float64
# 9    float64
# dtype: object

# %%
newdf[0][0] = "Apoorv"

# %%
newdf
# Out:
#             0         1         2         3         4         5         6  \
# 0      Apoorv  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             7         8         9
# 0    0.781762  0.110817  0.729273
# ...

# %%
newdf.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 newdf.dtypes
#
# NameError: name 'newdf' is not defined

# %%
apoorv
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
newdf = pd.DataFrame(np.random.rand(334, 10), index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.690284  0.646384  0.521778  0.313900  0.661506  0.002779  0.792307
# 1    0.712949  0.241897  0.180542  0.434821  0.961195  0.699264  0.815264
# 2    0.931200  0.214606  0.465992  0.113759  0.176204  0.023353  0.224634
# 3    0.428398  0.642746  0.164151  0.020528  0.851424  0.438059  0.928454
# 4    0.438579  0.806020  0.347348  0.563857  0.680551  0.315485  0.975525
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.703027  0.470646  0.346328  0.132201  0.244786  0.058232  0.671170
# 330  0.108702  0.264670  0.205583  0.920905  0.158452  0.899633  0.969645
# 331  0.769534  0.404066  0.814786  0.187529  0.877308  0.733329  0.720422
# 332  0.240731  0.359850  0.687686  0.907165  0.517655  0.932047  0.856377
# 333  0.677980  0.223803  0.991666  0.766515  0.837859  0.149764  0.438580
#
#             7         8         9
# 0    0.117914  0.496251  0.599623
# ...

# %%
newdf[0][0] = 34

# %%
newdf.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0        34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1  0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2   0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3  0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4  0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
#
#           7         8         9
# 0  0.781762  0.110817  0.729273
# 1  0.428690  0.242374  0.087754
# 2  0.731822  0.926760  0.026614
# 3  0.287069  0.270637  0.352553
# 4  0.910869  0.352032  0.351018

# %%
newdf.to_numpy()
# Out:
# array([[34, 0.12806743881419003, 0.9103102197043128, ...,
#         0.7817621229873226, 0.11081719534952017, 0.7292727041699759],
#        [0.3645194161383509, 0.6049401790501715, 0.19875416803530033, ...,
#         0.42868984168708524, 0.24237373245533245, 0.08775378334567108],
#        [0.5465103989091693, 0.9432236646073615, 0.10292712677450355, ...,
#         0.7318221063979519, 0.9267599710819702, 0.026613815750077707],
#        ...,
#        [0.08436403804589954, 0.75995267412361, 0.14624512518235422, ...,
#         0.19937194517677725, 0.5405488424871177, 0.4742080240875076],
#        [0.9416457584057711, 0.9814476791376349, 0.569626239033582, ...,
#         0.3069838064423205, 0.0008292299110240764, 0.3648144379354924],
#        [0.9646521811709504, 0.2001986196771287, 0.2845627145294394, ...,
#         0.7017969287255708, 0.06242117758009902, 0.16209606010766675]],
#       dtype=object)

# %%
newdf.sort_index(axis=0, ascending=False)
# Out:
#             0         1         2         3         4         5         6  \
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# ..        ...       ...       ...       ...       ...       ...       ...
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 0          34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
#
#             7         8         9
# 333  0.701797  0.062421  0.162096
# ...

# %%
newdf.columns = list("ABCDEFGHIJ")

# %%
newdf
# Out:
#             A         B         C         D         E         F         G  \
# 0          34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J
# 0    0.781762  0.110817  0.729273
# ...

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E         F         G  \
# 0        34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1  0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
#
#           H         I         J
# 0  0.781762  0.110817  0.729273
# 1  0.428690  0.242374  0.087754

# %%
newdf.loc[0, 0] = 65

# %%
newdf
# Out:
#             A         B         C         D         E         F         G  \
# 0          34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J     0
# ...

# %%
newdf.drop(0, axis=1)
# Out:
#             A         B         C         D         E         F         G  \
# 0          34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J
# 0    0.781762  0.110817  0.729273
# ...

# %%
newdf.head(0)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F, G, H, I, J, 0]
# Index: []

# %%
newdf.loc[[1, 2], :]
# Out:
#           A         B         C         D         E         F         G  \
# 1  0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2   0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
#
#           H         I         J   0
# 1  0.428690  0.242374  0.087754 NaN
# 2  0.731822  0.926760  0.026614 NaN

# %%
newdf
# Out:
#             A         B         C         D         E         F         G  \
# 0          34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J     0
# ...

# %%
newdf.loc[(newdf["A"]<0.3) & (newdf["C"]>0.1)]
# Out:
#             A         B         C         D         E         F         G  \
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 5    0.124412  0.135692  0.909339  0.052674  0.989800  0.199427  0.049448
# 6    0.259083  0.091172  0.242569  0.881802  0.229003  0.090825  0.216737
# 9    0.220336  0.125999  0.598488  0.450889  0.657242  0.283687  0.161633
# 14   0.183338  0.629724  0.266726  0.861561  0.802983  0.913486  0.732852
# ..        ...       ...       ...       ...       ...       ...       ...
# 319  0.235976  0.385727  0.127622  0.308661  0.424363  0.398490  0.666940
# 322  0.149365  0.499728  0.405267  0.433353  0.453216  0.844879  0.635347
# 328  0.229976  0.557591  0.895012  0.325704  0.515330  0.440395  0.453005
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
#
#             H         I         J   0
# 3    0.287069  0.270637  0.352553 NaN
# ...

# %%
newdf
# Out:
#             A         B         C         D         E         F         G  \
# 0          34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J     0
# ...

# %%
newdf.iloc[1, 4]
# Out:
# 0.11512859297085687

# %%
newdf.iloc[[0, 1], [1, 2]]
# Out:
#           B         C
# 0  0.128067  0.910310
# 1  0.604940  0.198754

# %%
newdf.head(3)
# Out:
#           A         B         C         D         E         F         G  \
# 0        34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1  0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2   0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
#
#           H         I         J     0
# 0  0.781762  0.110817  0.729273  65.0
# 1  0.428690  0.242374  0.087754   NaN
# 2  0.731822  0.926760  0.026614   NaN

# %%
newdf.drop(0)
# Out:
#             A         B         C         D         E         F         G  \
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# 5    0.124412  0.135692  0.909339  0.052674  0.989800  0.199427  0.049448
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J   0
# 1    0.428690  0.242374  0.087754 NaN
# ...

# %%
newdf.head(54)
# Out:
#            A         B         C         D         E         F         G  \
# 0         34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1   0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2    0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3   0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4   0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# 5   0.124412  0.135692  0.909339  0.052674  0.989800  0.199427  0.049448
# 6   0.259083  0.091172  0.242569  0.881802  0.229003  0.090825  0.216737
# 7   0.409939  0.181456  0.595363  0.544199  0.926684  0.161316  0.857138
# 8   0.581427  0.732246  0.350803  0.681871  0.447969  0.771195  0.990258
# 9   0.220336  0.125999  0.598488  0.450889  0.657242  0.283687  0.161633
# 10  0.577122  0.148128  0.707519  0.074205  0.996123  0.694532  0.028320
# 11  0.440876  0.351548  0.290065  0.832192  0.682693  0.205015  0.987215
# ...

# %%
newdf.drop(["A", "B"], axis=1)
# Out:
#             C         D         E         F         G         H         I  \
# 0    0.910310  0.126834  0.490748  0.182047  0.537244  0.781762  0.110817
# 1    0.198754  0.266357  0.115129  0.741551  0.851663  0.428690  0.242374
# 2    0.102927  0.334964  0.653297  0.144543  0.052297  0.731822  0.926760
# 3    0.351947  0.206406  0.735660  0.497812  0.869690  0.287069  0.270637
# 4    0.035426  0.495226  0.506147  0.809917  0.336656  0.910869  0.352032
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.357952  0.642707  0.393498  0.672660  0.348050  0.127412  0.866540
# 330  0.579400  0.607876  0.686640  0.037501  0.987094  0.191742  0.880008
# 331  0.146245  0.087147  0.364672  0.445569  0.883593  0.199372  0.540549
# 332  0.569626  0.365399  0.779223  0.143356  0.860716  0.306984  0.000829
# 333  0.284563  0.791669  0.676685  0.579087  0.879292  0.701797  0.062421
#
#             J     0
# 0    0.729273  65.0
# 1    0.087754   NaN
# ...

# %%
newdf
# Out:
#             A         B         C         D         E         F         G  \
# 0          34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J     0
# ...

# %%
newdf.drop([2, 5], axis=0)
# Out:
#             A         B         C         D         E         F         G  \
# 0          34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# 6    0.259083  0.091172  0.242569  0.881802  0.229003  0.090825  0.216737
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J     0
# ...

# %%
newdf
# Out:
#             A         B         C         D         E         F         G  \
# 0          34  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    0.364519  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2     0.54651  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    0.032969  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    0.279504  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.835573  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  0.095567  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  0.084364  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  0.941646  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  0.964652  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J     0
# ...

# %%
newdf["A"] = "Apoorv"

# %%
newdf["A"] = None

# %%
newdf
# Out:
#         A         B         C         D         E         F         G  \
# 0    None  0.128067  0.910310  0.126834  0.490748  0.182047  0.537244
# 1    None  0.604940  0.198754  0.266357  0.115129  0.741551  0.851663
# 2    None  0.943224  0.102927  0.334964  0.653297  0.144543  0.052297
# 3    None  0.310469  0.351947  0.206406  0.735660  0.497812  0.869690
# 4    None  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..    ...       ...       ...       ...       ...       ...       ...
# 329  None  0.341696  0.357952  0.642707  0.393498  0.672660  0.348050
# 330  None  0.810485  0.579400  0.607876  0.686640  0.037501  0.987094
# 331  None  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332  None  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333  None  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J     0
# 0    0.781762  0.110817  0.729273  65.0
# 1    0.428690  0.242374  0.087754   NaN
# ...

# %%
newdf.dtypes
# Out:
# A     object
# B    float64
# C    float64
# D    float64
# E    float64
# F    float64
# G    float64
# H    float64
# I    float64
# J    float64
# 0    float64
# dtype: object

# %%
newdf.loc[ [0, 2]] = "Apoorv"

# %%
newdf
# Out:
#           A         B         C         D         E         F         G  \
# 0    Apoorv    Apoorv    Apoorv    Apoorv    Apoorv    Apoorv    Apoorv
# 1        34   0.60494  0.198754  0.266357  0.115129  0.741551  0.851663
# 2    Apoorv    Apoorv    Apoorv    Apoorv    Apoorv    Apoorv    Apoorv
# 3        34  0.310469  0.351947  0.206406   0.73566  0.497812   0.86969
# 4        34  0.313806  0.035426  0.495226  0.506147  0.809917  0.336656
# ..      ...       ...       ...       ...       ...       ...       ...
# 329      34  0.341696  0.357952  0.642707  0.393498   0.67266   0.34805
# 330      34  0.810485    0.5794  0.607876   0.68664  0.037501  0.987094
# 331      34  0.759953  0.146245  0.087147  0.364672  0.445569  0.883593
# 332      34  0.981448  0.569626  0.365399  0.779223  0.143356  0.860716
# 333      34  0.200199  0.284563  0.791669  0.676685  0.579087  0.879292
#
#             H         I         J       0       2
# 0      Apoorv    Apoorv    Apoorv  Apoorv  Apoorv
# ...

# %%
df = pd.DataFrame({
    "name":['Apoorv', 'Harry', 'Rohan', 'Shubh'], 
    "marks":[92, 58, 66, 72], 
    "city":['Dindori', 'Rampur', 'Kolkata', 'Bareilly']
})

# %%
df
# Out:
#      name  marks      city
# 0  Apoorv     92   Dindori
# 1   Harry     58    Rampur
# 2   Rohan     66   Kolkata
# 3   Shubh     72  Bareilly

# %%
df.head()
# Out:
#      name  marks      city
# 0  Apoorv     92   Dindori
# 1   Harry     58    Rampur
# 2   Rohan     66   Kolkata
# 3   Shubh     72  Bareilly

# %%
df.dropna()
# Out:
#      name  marks      city
# 0  Apoorv     92   Dindori
# 1   Harry     58    Rampur
# 2   Rohan     66   Kolkata
# 3   Shubh     72  Bareilly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   marks   4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
create = pd.DataFrame(np.random.rand(3, 3), index=np.arange(3))

# %%
create
# Out:
#           0         1         2
# 0  0.382860  0.759996  0.017457
# 1  0.509918  0.578558  0.742107
# 2  0.450249  0.678819  0.261408

# %%
create.describe()
# Out:
#               0         1         2
# count  3.000000  3.000000  3.000000
# mean   0.447676  0.672458  0.340324
# std    0.063568  0.090886  0.368714
# min    0.382860  0.578558  0.017457
# 25%    0.416555  0.628688  0.139433
# 50%    0.450249  0.678819  0.261408
# 75%    0.480084  0.719407  0.501757
# max    0.509918  0.759996  0.742107

# %%
create.std()
# Out:
# 0    0.063568
# 1    0.090886
# 2    0.368714
# dtype: float64

# %%
create.mean()
# Out:
# 0    0.447676
# 1    0.672458
# 2    0.340324
# dtype: float64
